# %%
import pandas as pd

# %%
pd.read_json?

# %%
df = pd.read_json("https://data.sfgov.org/resource/b8d6-zthg.json")

# %%
df.describe()
# Out:
#            affhsg         app_id       appl_no        blklot        block  \
# count  229.000000     220.000000  2.220000e+02  2.120000e+02   223.000000
# mean     3.305677  758438.363636  2.002460e+11  3.806591e+06  3746.219731
# std     13.375908   97205.747989  1.350229e+10  2.352234e+06  2359.686580
# min      0.000000  210537.000000  9.410161e+06  2.603000e+04    26.000000
# 25%      0.000000  736437.000000  2.010347e+11  1.425289e+06  1265.000000
# 50%      0.000000  786216.000000  2.012083e+11  3.863548e+06  3753.000000
# 75%      1.000000  815372.250000  2.013072e+11  5.518531e+06  5512.000000
# max    150.000000  862658.000000  2.014111e+11  8.711025e+06  8711.000000
#
#              form         lot    netunits          pd       st_num       units
# count  229.000000  217.000000  229.000000  229.000000   229.000000  229.000000
# mean     3.960699   40.064516   15.344978    7.484716  1144.510917   23.353712
# ...

# %%
df.head(5)
# Out:
#      actdate      action  affhsg                    ana_nbhd    app_id  \
# 0  27-Mar-14    COMPLETE       0                    Nob Hill  748144.0
# 1  24-Jun-14    COMPLETE       0                   Chinatown  847144.0
# 2  07-Aug-14    COMPLETE       2                     Mission  786469.0
# 3  12-Sep-14  CFC ISSUED       0  Oceanview/Merced/Ingleside  853085.0
# 4  06-Nov-14  CFC ISSUED       0                Potrero Hill  840139.0
#
#         appl_no     blklot   block  \
# 0  2.011052e+11   223008.0   223.0
# 1  2.014062e+11   211015.0   211.0
# 2  2.012083e+11  3533001.0  3533.0
# 3  2.014081e+11  6985010.0  6985.0
# 4  2.014041e+11  4219003.0  4219.0
#
#                                             descript           existuse  \
# 0  Install auto fire sprinkler to protect addiiti...         APARTMENTS
# 1  CORRECT RECORD TO INCORPORATE SUPERINTENDANTS ...         APARTMENTS
# 2   4TH FLOOR VERTICAL ADDITION OF 2 DWELLING UNITS.         APARTMENTS
# ...
