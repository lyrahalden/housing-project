# %%
import pandas as pd

# %%
pwd
# Out:
# u'/home/user/src/lyra_project/j_nbs'

# %%
df = pd.read_csv("../datasets/num_new_units_recent/SF_Development_Pipeline_2016_Q1.csv")

# %%
df.head()
# Out:
#   PROJECT_TYPE           APN                           NAMEADDR Alias  \
# 0          CIE   APN 4712008  1 ARDATH COURT (COMMUNITY CENTER)   NaN
# 1     Resident   APN 6978069                         1 EDGAR AV   NaN
# 2       Mixres   APN 0837003                      1 FRANKLIN ST   NaN
# 3     Resident   APN 3911001                   1 HENRY ADAMS ST   NaN
# 4     Resident  APN 6525001A                        1 HORACE ST   NaN
#
#      BESTDATE      BESTSTAT  Entitlement      PLN_CASENO  \
# 0  12/17/2015      BP FILED            0  2015-003310PRJ
# 1  05/08/2015      BP FILED            0             NaN
# 2  03/28/2016  CONSTRUCTION           -1       2010.0102
# 3  03/17/2016  CONSTRUCTION           -1       2012.0701
# 4  09/24/2014      BP FILED            0       2014.1301
#
#                                             PLN_DESC     BP_APPLNO  \
# 0  New construction of a community center to be l...  201512175326
# ...

# %%
res_df = df.loc[(df['PROJECT_TYPE'] == 'Resident') | (df['PROJECT_TYPE'] == 'Mixres')]

# %%
res_df.head()
# Out:
#   PROJECT_TYPE           APN          NAMEADDR Alias    BESTDATE  \
# 1     Resident   APN 6978069        1 EDGAR AV   NaN  05/08/2015
# 2       Mixres   APN 0837003     1 FRANKLIN ST   NaN  03/28/2016
# 3     Resident   APN 3911001  1 HENRY ADAMS ST   NaN  03/17/2016
# 4     Resident  APN 6525001A       1 HORACE ST   NaN  09/24/2014
# 5       Mixres  APN 1084001B      1 STANYAN ST   NaN  10/22/2015
#
#        BESTSTAT  Entitlement PLN_CASENO  \
# 1      BP FILED            0        NaN
# 2  CONSTRUCTION           -1  2010.0102
# 3  CONSTRUCTION           -1  2012.0701
# 4      BP FILED            0  2014.1301
# 5   BP APPROVED           -1  2007.0113
#
#                                             PLN_DESC     BP_APPLNO  \
# 1                                                NaN  201505085755
# 2  Construct a new 8-story, 35-unit mixed-use bui...  200912032516
# 3  Demolish an existing building (Concourse Exhib...  201306250394
# ...

# %%
res_df.insert(0, 'New_ID', range(len(res_df)))

# %%
res_df.set_index('New_ID', inplace=True)

# %%
useful_df = res_df[['LOCATION','NEIGHBORHOOD','NET_AFF_UNITS','NET_UNITS']]

# %%
useful_df.head()
# Out:
#                             LOCATION           NEIGHBORHOOD  NET_AFF_UNITS  \
# New_ID
# 0       (37.7203939917, -122.452521)             Ocean View              0
# 1       (37.7744289168, -122.421110)  Downtown/Civic Center              5
# 2       (37.7692014331, -122.403473)        South of Market              0
# 3       (37.7507228458, -122.414398)                Mission              0
# 4       (37.7810723620, -122.456522)         Inner Richmond              0
#
#        NET_UNITS
# New_ID
# 0              1
# 1             35
# 2            560
# 3              1
# 4             13

# %%
useful_df.to_csv("../datasets/num_new_units_recent/2016_Q1.csv", sep='|', na_rep='-')
